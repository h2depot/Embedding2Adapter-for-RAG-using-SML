# %% [markdown]
# # Training comparison
#
# Compare MeanEmbds (2026-08-13) and QueryDiffPooling (2026-08-15) using separate training-loss and validation-token-F1 plots.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = next(
    (path for path in (Path.cwd(), *Path.cwd().parents)
     if (path / "pyproject.toml").exists()),
    None,
)
if PROJECT_ROOT is None:
    raise RuntimeError("Project root could not be found.")

project_root = str(PROJECT_ROOT)
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from Experiment.scripts.visualizer import plot_training_comparison

# %%
RESULT_DIR = PROJECT_ROOT / "Experiment" / "Result"
MEAN_RESULT = RESULT_DIR / "experiment_2026_08_13.json"
QDIFF_RESULT = RESULT_DIR / "experiment_2026_08_15.json"

loss_plot, validation_accuracy_plot = plot_training_comparison(
    mean_result_path=MEAN_RESULT,
    qdiff_result_path=QDIFF_RESULT,
)
